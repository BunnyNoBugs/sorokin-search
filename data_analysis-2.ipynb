# %% [markdown]
# # Анализ данных на основе корпуса

# %%
import json  # импорт джейсона

# %%
from pprint import pprint #подключили Pprint для красоты выдачи текста
 
with open('processed_data.json', 'r', encoding='utf-8') as f: #открыли файл с данными
    text = json.load(f) #загнали все, что получилось в переменную
    pprint(text[0])
# Out:
# ['Очередь',
#  [{'token': ' \n'},
#   {'token': '— '},
#   {'POS': 'S', 'lemma': 'товарищ', 'token': 'Товарищи'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'кто', 'token': 'кто'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'последний', 'token': 'последний'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'наверное', 'token': 'Наверное'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'но', 'token': 'но'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'мной'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'еще', 'token': 'еще'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'женщина', 'token': 'женщина'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'в', 'token': 'в'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'синий', 'token': 'синем'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'пальто', 'token': 'пальто'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'значит', 'token': 'Значит'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'она', 'token': 'ней'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'Да'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'она', 'token': 'Она'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'щас', 'token': 'щас'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'прийти', 'token': 'придет'},
#   {'token': '. '},
#   {'POS': 'V', 'lemma': 'становиться', 'token': 'Становитесь'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'мной'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'пока', 'token': 'пока'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'Вы'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'быть', 'token': 'будете'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стоять'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'Да'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'на'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'минута', 'token': 'минуту'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'отходить', 'token': 'отойти'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'хотеть', 'token': 'хотел'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'буквально', 'token': 'буквально'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'на'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'минута', 'token': 'минуту'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'хорошо', 'token': 'Лучше'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'наверное', 'token': 'наверное'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'она', 'token': 'ее'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'дождаться', 'token': 'дождаться'},
#   {'token': '. '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'то', 'token': 'то'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'подходить', 'token': 'подойдут'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'мне'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'что', 'token': 'что'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'объяснять', 'token': 'объяснить'},
#   {'token': '? '},
#   {'POS': 'V', 'lemma': 'подождать', 'token': 'Подождите'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'она', 'token': 'Она'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'сказать', 'token': 'сказала'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'что', 'token': 'что'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'быстро', 'token': 'быстро'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'ладно', 'token': 'Ладно'},
#   {'token': '. '},
#   {'POS': 'V', 'lemma': 'подождать', 'token': 'Подожду'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'Вы'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'давно', 'token': 'давно'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стоите'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'очень', 'token': 'очень'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'знать', 'token': 'знаете'},
#   {'token': ', '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'сколько', 'token': 'сколько'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'давать', 'token': 'дают'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'S', 'lemma': 'черт', 'token': 'Черт'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'их'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'знать', 'token': 'знает'},
#   {'token': '... '},
#   {'POS': 'PART', 'lemma': 'даже', 'token': 'Даже'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'и', 'token': 'и'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'спрашивать', 'token': 'спрашивал'},
#   {'token': '. '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'Не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'знать', 'token': 'знаете'},
#   {'token': ', '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'сколько', 'token': 'сколько'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'давать', 'token': 'дают'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'сегодня', 'token': 'Сегодня'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'знать', 'token': 'знаю'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'слышать', 'token': 'слышала'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'вчера', 'token': 'вчера'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'два', 'token': 'два'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'давать', 'token': 'давали'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'По'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'два', 'token': 'два'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'INTJ', 'lemma': 'ага', 'token': 'Ага'},
#   {'token': '. '},
#   {'POS': 'ADV', 'lemma': 'сначала', 'token': 'Сначала'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'четыре', 'token': 'четыре'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'потом', 'token': 'потом'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'два', 'token': 'два'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'мало', 'token': 'Мало'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'как', 'token': 'как'},
#   {'token': '! '},
#   {'POS': 'ADVPRO', 'lemma': 'так', 'token': 'Так'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'и', 'token': 'и'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стоять'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'смысл', 'token': 'смысла'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'нет', 'token': 'нет'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'займите'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'два', 'token': 'две'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'очередь', 'token': 'очереди'},
#   {'token': '. '},
#   {'POS': 'ADVPRO', 'lemma': 'тут', 'token': 'Тут'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'приезжий', 'token': 'приезжие'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'три', 'token': 'три'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'занимают'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'По'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'три', 'token': 'три'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'INTJ', 'lemma': 'ага', 'token': 'Ага'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADVPRO', 'lemma': 'так', 'token': 'Так'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'это', 'token': 'это'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'целый', 'token': 'целый'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'день', 'token': 'день'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стоять'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'что', 'token': 'что'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': '. '},
#   {'POS': 'ADVPRO', 'lemma': 'тут', 'token': 'Тут'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'быстро', 'token': 'быстро'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'отпускать', 'token': 'отпускают'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'что-то', 'token': 'Чего-то'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'вериться', 'token': 'верится'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'мы', 'token': 'Мы'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'вон', 'token': 'вон'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'с', 'token': 'с'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'место', 'token': 'места'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'сдвигаться', 'token': 'сдвинулись'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'это', 'token': 'Это'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'там'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'подходить', 'token': 'подошли'},
#   {'token': ', '},
#   {'POS': 'APRO', 'lemma': 'который', 'token': 'которые'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'отходить', 'token': 'отходили'},
#   {'token': '. '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'Там'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'много', 'token': 'много'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'отходить', 'token': 'Отойдут'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'потом', 'token': 'потом'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'подваливать', 'token': 'подваливают'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'ничего', 'token': 'Ничего'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'щас', 'token': 'щас'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'быстро', 'token': 'быстро'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'пойти', 'token': 'пойдет'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'Вы'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'знать', 'token': 'знаете'},
#   {'token': ', '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'сколько', 'token': 'сколько'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'давать', 'token': 'дают'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'говорить', 'token': 'Говорят'},
#   {'token': ', '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'три', 'token': 'три'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'ну', 'token': 'Ну'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'это', 'token': 'это'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'еще', 'token': 'еще'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'нормально', 'token': 'нормально'},
#   {'token': '! '},
#   {'POS': 'PR', 'lemma': 'возле', 'token': 'Возле'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'савеловский', 'token': 'Савеловского'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'вообще', 'token': 'вообще'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'один', 'token': 'одному'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADVPRO', 'lemma': 'так', 'token': 'Так'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'там'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'нет', 'token': 'нет'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'смысл', 'token': 'смысла'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'вообще', 'token': 'вообще'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'больше', 'token': 'больше'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'давать', 'token': 'давать'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'все', 'token': 'все'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'равный', 'token': 'равно'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'приезжий', 'token': 'приезжие'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'разбирать', 'token': 'разберут'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'все', 'token': 'все'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'сказать', 'token': 'Скажите'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'вчера', 'token': 'вчера'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'очередь', 'token': 'очередь'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'такой', 'token': 'такая'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'же', 'token': 'же'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'быть', 'token': 'была'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'почти', 'token': 'Почти'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'и', 'token': 'и'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'вчера', 'token': 'вчера'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стояли'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'Стояла'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'долго', 'token': 'Долго'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'очень', 'token': 'очень'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'Не'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'очень', 'token': 'очень'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'мять', 'token': 'мятые'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'вначале', 'token': 'Вначале'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ничто', 'token': 'ничего'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'под', 'token': 'под'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'конец', 'token': 'конец'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'всякий', 'token': 'всякие'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'быть', 'token': 'были'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'сегодня', 'token': 'Сегодня'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'тоже', 'token': 'тоже'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'наверное', 'token': 'наверное'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'хорошо', 'token': 'получше'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'разбирать', 'token': 'разберут'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'плохой', 'token': 'плохие'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'мы', 'token': 'нам'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'доставаться', 'token': 'достанутся'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'весь', 'token': 'все'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'одинаковый', 'token': 'одинаковые'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'видеть', 'token': 'видел'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'S', 'lemma': 'правда', 'token': 'Правда'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'INTJ', 'lemma': 'ага', 'token': 'Ага'},
#   {'token': '. '},
#   {'POS': 'A', 'lemma': 'плохой', 'token': 'Плохие'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'отбирать', 'token': 'отбирают'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'Да'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'отбирать', 'token': 'отберут'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': '! '},
#   {'POS': 'V', 'lemma': 'ждать', 'token': 'Жди'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'A', 'lemma': 'обязанный', 'token': 'Обязаны'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'отбирать', 'token': 'отбирать'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'и', 'token': 'и'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'списывать', 'token': 'списывать'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'бросать', 'token': 'бросьте'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': '! '},
#   {'POS': 'A', 'lemma': 'обязанный', 'token': 'Обязаны'},
#   {'token': '! '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'Они'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'наживаться', 'token': 'наживаются'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'на'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'это', 'token': 'этом'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'быть', 'token': 'будь'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'здоровый', 'token': 'здоров'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'ну', 'token': 'Ну'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'посмотреть', 'token': 'посмотрим'},
#   {'token': ', '},
#   {'POS': 'ADVPRO', 'lemma': 'чего', 'token': 'чего'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'спорить', 'token': 'спорить'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'вон', 'token': 'Вон'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'женщина', 'token': 'женщина'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'идти', 'token': 'идет'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'Вы'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'она', 'token': 'ней'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'это', 'token': 'Это'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'тот', 'token': 'та'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'высокий', 'token': 'высокая'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'Да'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вами'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'значит', 'token': 'значит'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'наверное', 'token': 'Наверное'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'вот', 'token': 'вот'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'этот', 'token': 'этим'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'гражданин', 'token': 'гражданином'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADVPRO', 'lemma': 'тогда', 'token': 'Тогда'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вами'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вами'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'мной'},
#   {'token': ', '},
#   {'POS': 'A', 'lemma': 'хороший', 'token': 'хорошо'},
#   {'token': '. '},
#   {'POS': 'ADV', 'lemma': 'теперь', 'token': 'Теперь'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'мне'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'отходить', 'token': 'отойти'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'можно', 'token': 'можно'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'конечно', 'token': 'Конечно'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'на'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'минутка', 'token': 'минутку'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'мне'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'белье', 'token': 'белье'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'получать', 'token': 'получить'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'это', 'token': 'это'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'рядом', 'token': 'рядом'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'Они'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'до', 'token': 'до'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'шесть', 'token': 'шести'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'сегодня', 'token': 'сегодня'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'кажется', 'token': 'Кажется'},
#   {'token': ', '},
#   {'POS': 'PR', 'lemma': 'до', 'token': 'до'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'шесть', 'token': 'шести'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'тогда', 'token': 'тогда'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'поздно', 'token': 'попозже'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'сбегать', 'token': 'сбегаю'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'Вы'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'видеть', 'token': 'видели'},
#   {'token': ', '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'там'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'капуста', 'token': 'капусту'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'привозить', 'token': 'привезли'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'нет', 'token': 'Нет'},
#   {'token': '. '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'Там'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'апельсин', 'token': 'апельсинами'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'очередь', 'token': 'очередь'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'капуста', 'token': 'капусты'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'нет', 'token': 'нет'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADVPRO', 'lemma': 'так', 'token': 'Так'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'она', 'token': 'она'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'плохой', 'token': 'плохая'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'еще', 'token': 'еще'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'она', 'token': 'ее'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'брать', 'token': 'брать'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'смысл', 'token': 'смысла'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'нет', 'token': 'нет'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'На'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'ленинский', 'token': 'Ленинском'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'давать', 'token': 'давали'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'молодой', 'token': 'молодую'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'вполне', 'token': 'вполне'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'хороший', 'token': 'хорошая'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'ну', 'token': 'ну'},
#   {'token': '! '},
#   {'POS': 'APRO', 'lemma': 'один', 'token': 'Одни'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'лист', 'token': 'листья'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'A', 'lemma': 'молодой', 'token': 'Молодая'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'очень', 'token': 'очень'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'полезный', 'token': 'полезная'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'вон', 'token': 'Вон'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'подходить', 'token': 'подходят'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'как', 'token': 'как'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'совсем', 'token': 'совсем'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'обнаглеть', 'token': 'обнаглели'},
#   {'token': '. '},
#   {'POS': 'S', 'lemma': 'мужчина', 'token': 'Мужчина'},
#   {'token': ', '},
#   {'POS': 'ADVPRO', 'lemma': 'зачем', 'token': 'зачем'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'пропускать', 'token': 'пропускаете'},
#   {'token': '?! '},
#   {'POS': 'SPRO', 'lemma': 'что', 'token': 'Что'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'мы', 'token': 'нам'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'целый', 'token': 'целый'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'день', 'token': 'день'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стоять'},
#   {'token': '?! '},
#   {'POS': 'V', 'lemma': 'подходить', 'token': 'Подходят'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'подходить', 'token': 'подходят'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'Они'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'занимали'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'отходить', 'token': 'отошли'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'просто', 'token': 'просто'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ничто', 'token': 'ничего'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'занимали'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'мы', 'token': 'Мы'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'занимали'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'что', 'token': 'чего'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'кричать', 'token': 'кричите'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'ничто', 'token': 'Ничего'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'занимали'},
#   {'token': '! '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'здесь', 'token': 'здесь'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'с', 'token': 'с'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'самый', 'token': 'самого'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'утро', 'token': 'утра'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стою'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'Они'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'занимали'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'видеть', 'token': 'видела'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'Займут'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'сам', 'token': 'сами'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'уходить', 'token': 'уйдут'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'на'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'полдень', 'token': 'полдня'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'по-моему', 'token': 'по-моему'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'занимали'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'их'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'видеть', 'token': 'видел'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'Занимали'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'Занимали'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'занимали'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'занимать', 'token': 'занимали'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'успокаиваться', 'token': 'успокойтесь'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'APRO', 'lemma': 'сам', 'token': 'Сами'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'успокаиваться', 'token': 'успокойтесь'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'ладно', 'token': 'Ладно'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'надо', 'token': 'надо'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'кричать', 'token': 'кричать'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'из-за', 'token': 'из-за'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'пустяк', 'token': 'пустяка'},
#   {'token': '. '},
#   {'POS': 'S', 'lemma': 'человек', 'token': 'Люди'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стояли'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'отходить', 'token': 'отошли'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'ничто', 'token': 'Ничего'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'страшный', 'token': 'страшного'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'что-то', 'token': 'Чего-то'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'она', 'token': 'она'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'медленно', 'token': 'медленно'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'отпускать', 'token': 'отпускает'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'видеть', 'token': 'видите'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'немного', 'token': 'Немного'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'APRO', 'lemma': 'тот', 'token': 'Та'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'рыжий', 'token': 'рыжая'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'плохо', 'token': 'плохо'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'отпускать', 'token': 'отпускает'},
#   {'token': '. '},
#   {'POS': 'ADV', 'lemma': 'вчера', 'token': 'Вчера'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'как', 'token': 'как'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'вареный', 'token': 'вареная'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'двигаться', 'token': 'двигалась'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'там'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'один', 'token': 'одна'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'разве', 'token': 'разве'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'NUM', 'lemma': 'два', 'token': 'Две'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'видеть', 'token': 'вижу'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'подходить', 'token': 'подойдите'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'сюда', 'token': 'сюда'},
#   {'token': ', '},
#   {'POS': 'ADVPRO', 'lemma': 'тут', 'token': 'тут'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'видно', 'token': 'видно'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'да'},
#   {'token': '. '},
#   {'POS': 'NUM', 'lemma': 'два', 'token': 'Две'},
#   {'token': '. '},
#   {'POS': 'APRO', 'lemma': 'тот', 'token': 'Та'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'вроде', 'token': 'вроде'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'побойкий', 'token': 'побойчей'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'A', 'lemma': 'черненький', 'token': 'Черненькая'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'быстро', 'token': 'быстрей'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'отпускать', 'token': 'отпускает'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'оба', 'token': 'обе'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'нормально', 'token': 'нормально'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'работать', 'token': 'работают'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'просто', 'token': 'просто'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'народ', 'token': 'народу'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'много', 'token': 'много'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'S', 'lemma': 'народ', 'token': 'Народу'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'всегда', 'token': 'всегда'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'много', 'token': 'много'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'тот', 'token': 'те'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'еще', 'token': 'еще'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'копаться', 'token': 'копаются'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'выбирать', 'token': 'выбирают'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADVPRO', 'lemma': 'так', 'token': 'Так'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'совсем', 'token': 'совсем'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'ни', 'token': 'ни'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'с', 'token': 'с'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'место', 'token': 'места'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'ничего', 'token': 'Ничего'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'щас', 'token': 'щас'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'быстро', 'token': 'побыстрей'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'пойти', 'token': 'пойдет'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'хоть', 'token': 'Хоть'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'бы', 'token': 'бы'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'три', 'token': 'три'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'давать', 'token': 'давали'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'давать', 'token': 'Дадут'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'успевать', 'token': 'Успеть'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'бы', 'token': 'бы'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'мы', 'token': 'Нам'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'хватить', 'token': 'хватит'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'вчера', 'token': 'Вчера'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'когда', 'token': 'когда'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'кончаться', 'token': 'кончились'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'знать', 'token': 'знаете'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'Не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'помнить', 'token': 'помню'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'что-то', 'token': 'что-то'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'уходить', 'token': 'ушла'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'прощать', 'token': 'Простите'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вами'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'нет', 'token': 'Нет'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'впереди', 'token': 'впереди'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'да'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'за'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вами'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'За'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'мной'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'еле', 'token': 'Еле'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'успевать', 'token': 'успел'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'что', 'token': 'что'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'рано', 'token': 'рано'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'закрывать', 'token': 'закрывают'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'сегодня', 'token': 'сегодня'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PR', 'lemma': 'за', 'token': 'За'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'мной'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'уже', 'token': 'уже'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'пускать', 'token': 'пускали'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'надо', 'token': 'Надо'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'же', 'token': 'же'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'сказать', 'token': 'Скажите'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'масло', 'token': 'масло'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вы'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'на'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'тот', 'token': 'той'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'сторона', 'token': 'стороне'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'брать', 'token': 'брали'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'нет', 'token': 'Нет'},
#   {'token': ', '},
#   {'POS': 'PR', 'lemma': 'в', 'token': 'в'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'центр', 'token': 'центре'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'На'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'тот', 'token': 'той'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'утро', 'token': 'утром'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'быть', 'token': 'было'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'три', 'token': 'три'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'пятьдесят', 'token': 'пятьдесят'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'щас', 'token': 'щас'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'нет', 'token': 'нет'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ничто', 'token': 'ничего'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PR', 'lemma': 'у', 'token': 'У'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'них'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'после', 'token': 'после'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'обед', 'token': 'обеда'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'бывать', 'token': 'бывает'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'S', 'lemma': 'утро', 'token': 'Утром'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'тоже', 'token': 'тоже'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'иногда', 'token': 'иногда'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'привозить', 'token': 'привозят'},
#   {'token': '... '},
#   {'POS': 'PART', 'lemma': 'ну', 'token': 'Ну'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'что', 'token': 'что'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'там'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': '. '},
#   {'POS': 'V', 'lemma': 'трепиться', 'token': 'Трепятся'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'час', 'token': 'часу'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'опять', 'token': 'Опять'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'грузин', 'token': 'грузины'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'подходить', 'token': 'подошли'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'во', 'token': 'во'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'видеть', 'token': 'видите'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'видеть', 'token': 'видите'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'как', 'token': 'как'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'у', 'token': 'у'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'он', 'token': 'него'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'просто', 'token': 'просто'},
#   {'token': '! '},
#   {'POS': 'S', 'lemma': 'женщина', 'token': 'Женщина'},
#   {'token': '! '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'Не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'пропускать', 'token': 'пропускайте'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'их'},
#   {'token': '! '},
#   {'POS': 'S', 'lemma': 'наглец', 'token': 'Наглецы'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'набирать', 'token': 'Наберут'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'по', 'token': 'по'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'двадцать', 'token': 'двадцать'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'штука', 'token': 'штук'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'потом', 'token': 'потом'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'перепродавать', 'token': 'перепродают'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'это', 'token': 'Это'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'ясный', 'token': 'ясно'},
#   {'token': '... '},
#   {'POS': 'PART', 'lemma': 'вот', 'token': 'Вот'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'правильно', 'token': 'правильно'},
#   {'token': '. '},
#   {'POS': 'CONJ', 'lemma': 'и', 'token': 'И'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'это', 'token': 'этого'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'тоже', 'token': 'тоже'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'гнать', 'token': 'гони'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'Вы'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'знать', 'token': 'знаете'},
#   {'token': ', '},
#   {'POS': 'APRO', 'lemma': 'этот', 'token': 'эта'},
#   {'token': ' '},
# ...
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'S', 'lemma': 'заведующая', 'token': 'Заведующей'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'сектор', 'token': 'сектора'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'очередь', 'token': 'очередь'},
#   {'token': '? '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'Не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'понимать', 'token': 'пойму'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ничто', 'token': 'ничего'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'там'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'же', 'token': 'же'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'очередь', 'token': 'очередь'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоить', 'token': 'стоит'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'пусть', 'token': 'пусть'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стоит'},
#   {'token': '. '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'Они'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'до', 'token': 'до'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'послезавтра', 'token': 'послезавтра'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'стоять', 'token': 'стоять'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'быть', 'token': 'будут'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'ты'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'что', 'token': 'что'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'иметь', 'token': 'имела'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'к', 'token': 'к'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'это', 'token': 'этому'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'какой-то', 'token': 'какое-то'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'отношение', 'token': 'отношение'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'ну', 'token': 'Ну'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'да'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'да'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'да'},
#   {'token': '! '},
#   {'POS': 'APRO', 'lemma': 'какой', 'token': 'Какой'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'ты'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'непонятливый', 'token': 'непонятливый'},
#   {'token': '! '},
#   {'POS': 'SPRO', 'lemma': 'мы', 'token': 'Мы'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'торговать', 'token': 'торгуем'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'мы', 'token': 'мы'},
#   {'token': '! '},
#   {'POS': 'APRO', 'lemma': 'мой', 'token': 'Мои'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'девочка', 'token': 'девочки'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'и', 'token': 'и'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': '! '},
#   {'POS': 'PART', 'lemma': 'просто', 'token': 'Просто'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'вчера', 'token': 'вчера'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'перед', 'token': 'перед'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'дождь', 'token': 'дождем'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'уходить', 'token': 'ушла'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'рано', 'token': 'пораньше'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADVPRO', 'lemma': 'так', 'token': 'Так'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'это', 'token': 'это'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'ты'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'там'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'да'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'ложиться', 'token': 'ложись'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'INTJ', 'lemma': 'господи', 'token': 'Господи'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'ну', 'token': 'ну'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'это', 'token': 'это'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'вообще', 'token': 'вообще'},
#   {'token': '!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'ложиться', 'token': 'Ложись'},
#   {'token': ', '},
#   {'POS': 'S', 'lemma': 'вадик', 'token': 'Вадик'},
#   {'token': '. '},
#   {'POS': 'APRO', 'lemma': 'весь', 'token': 'Всю'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'ночь', 'token': 'ночь'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'тереть', 'token': 'тер'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'меня'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'теперь', 'token': 'теперь'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'спать', 'token': 'спать'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'давать', 'token': 'даешь'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADVPRO', 'lemma': 'так', 'token': 'Так'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'значит', 'token': 'значит'},
#   {'token': ', '},
#   {'POS': 'ADV', 'lemma': 'сейчас', 'token': 'сейчас'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'просто', 'token': 'просто'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'нет', 'token': 'нет'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'никакой', 'token': 'никакой'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'продажа', 'token': 'продажи'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'нет', 'token': 'Нет'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'нет', 'token': 'нет'},
#   {'token': '! '},
#   {'POS': 'APRO', 'lemma': 'весь', 'token': 'Весь'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'товар', 'token': 'товар'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'идти', 'token': 'идет'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'на'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'склад', 'token': 'склад'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'до', 'token': 'до'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'послезавтра', 'token': 'послезавтра'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'не', 'token': 'не'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'успевать', 'token': 'успели'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'мы', 'token': 'мы'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'до', 'token': 'до'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'учет', 'token': 'учета'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'продавать', 'token': 'продать'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'там', 'token': 'там'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'штука', 'token': 'штук'},
#   {'token': ' '},
#   {'POS': 'NUM', 'lemma': 'триста', 'token': 'триста'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'еще', 'token': 'еще'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'они', 'token': 'они'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'точно', 'token': 'точно'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'американский', 'token': 'американские'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'точно', 'token': 'Точно'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'ложиться', 'token': 'ляжешь'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'ты'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'или', 'token': 'или'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'нет', 'token': 'нет'},
#   {'token': '?!'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'ложиться', 'token': 'Ложусь'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'ложиться', 'token': 'ложусь'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'слушать', 'token': 'слушай'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'а'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'если', 'token': 'если'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'у', 'token': 'у'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'вы', 'token': 'вас'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'учет', 'token': 'учет'},
#   {'token': ', '},
#   {'POS': 'ADVPRO', 'lemma': 'почему', 'token': 'почему'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'ты'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'дома', 'token': 'дома'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'на', 'token': 'на'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'больничный', 'token': 'больничном'},
#   {'token': '.'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'понарошку', 'token': 'Понарошку'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'конечно', 'token': 'Конечно'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'пускай', 'token': 'пускай'},
#   {'token': ' '},
#   {'POS': 'PR', 'lemma': 'без', 'token': 'без'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'меня'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'икра', 'token': 'икру'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'метать', 'token': 'мечут'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'влипать', 'token': 'влипли'},
#   {'token': ', '},
#   {'POS': 'PART', 'lemma': 'пусть', 'token': 'пусть'},
#   {'token': ' '},
#   {'POS': 'CONJ', 'lemma': 'и', 'token': 'и'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'выкручиваться', 'token': 'выкручиваются'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'A', 'lemma': 'тепленький', 'token': 'Тепленькая'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'мой', 'token': 'моя'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'подвигаться', 'token': 'подвинься'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'Я'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'тебе'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'вчера', 'token': 'вчера'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'сказать', 'token': 'сказать'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'хотеть', 'token': 'хотела'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'да'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'забывать', 'token': 'забыла'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'после', 'token': 'после'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'а', 'token': 'А'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'зачем', 'token': 'зачем'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'же', 'token': 'же'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'ты'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'наврать', 'token': 'наврала'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'мне'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'что', 'token': 'что'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'ты'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'экономист', 'token': 'экономист'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'CONJ', 'lemma': 'да', 'token': 'Да'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'так', 'token': 'так'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'просто', 'token': 'просто'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'сразу', 'token': 'сразу'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'понимать', 'token': 'поняла'},
#   {'token': ', '},
#   {'POS': 'CONJ', 'lemma': 'что', 'token': 'что'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'ты'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'парень', 'token': 'парень'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'интеллигентный', 'token': 'интеллигентный'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'знать', 'token': 'знаешь'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'как', 'token': 'как'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'S', 'lemma': 'глупышка', 'token': 'Глупышка'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'какой', 'token': 'какое'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'это', 'token': 'это'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'иметь', 'token': 'имеет'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'значение', 'token': 'значение'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'прелесть', 'token': 'прелесть'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'мой', 'token': 'моя'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'обнимать', 'token': 'Обними'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'меня'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'S', 'lemma': 'чудачка', 'token': 'Чудачка'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'APRO', 'lemma': 'такой', 'token': 'такие'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'неожиданность', 'token': 'неожиданности'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'ADV', 'lemma': 'прямо', 'token': 'прямо'},
#   {'token': ' '},
#   {'POS': 'A', 'lemma': 'необычный', 'token': 'необычное'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'лето', 'token': 'лето'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'S', 'lemma': 'парад', 'token': 'Парад'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'планета', 'token': 'планет'},
#   {'token': ', '},
#   {'POS': 'ADVPRO', 'lemma': 'чего', 'token': 'чего'},
#   {'token': ' '},
#   {'POS': 'PART', 'lemma': 'ж', 'token': 'ж'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'ты'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'хотеть', 'token': 'хочешь'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'PART', 'lemma': 'да', 'token': 'Да'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'ADV', 'lemma': 'оооой', 'token': 'Оооой'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'спать', 'token': 'спи'},
#   {'token': ', '},
#   {'POS': 'S', 'lemma': 'котик', 'token': 'котик'},
#   {'token': '...'},
#   {'token': ' '},
#   {'POS': 'ADVPRO', 'lemma': 'потом', 'token': 'потом'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'вставать', 'token': 'встанем'},
#   {'token': ', '},
#   {'POS': 'SPRO', 'lemma': 'я', 'token': 'я'},
#   {'token': ' '},
#   {'POS': 'SPRO', 'lemma': 'ты', 'token': 'тебе'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'цыпленок', 'token': 'цыплят'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'табак', 'token': 'табака'},
#   {'token': ' '},
#   {'POS': 'V', 'lemma': 'сделать', 'token': 'сделаю'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'спать', 'token': 'Сплю'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'любить', 'token': 'Любишь'},
#   {'token': ' '},
#   {'POS': 'S', 'lemma': 'табак', 'token': 'табака'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'любить', 'token': 'Люблю'},
#   {'token': '...'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'спать', 'token': 'Спишь'},
#   {'token': '?'},
#   {'token': '\n'},
#   {'token': '— '},
#   {'POS': 'V', 'lemma': 'спать', 'token': 'Сплю'},
#   {'token': ', '},
#   {'POS': 'V', 'lemma': 'спать', 'token': 'сплю'},
#   {'token': '...'},
#   {'token': '\n'}]]

# %% [markdown]
# # Посмотрим на POS-теги

# %%
pos_tags = ''
lemmas = ''
kniga = ''
roman = 0
for i in text[roman]:
    s = 0
    for t in text[roman][1]:
        try:
            pos_tags += text[roman][1][s]['POS']
            pos_tags += ' '
            lemmas += text[roman][1][s]['lemma']
            lemmas += ' '

            kniga += text[roman][0]
            kniga += ','
            s += 1
        except KeyError:
            s += 1
    roman += 1

# %%
len(kniga.split(','))
# Out:
# 85503

# %%
from collections import Counter

# %%
Counter(pos_tags.split(' ')).most_common(3)
# Out:
# [('S', 24794), ('V', 16259), ('A', 7107)]

# %%
a = Counter(pos_tags.split(' ')).most_common(10)

tag = []
value = []

s = 0
for i in a:
    tag.append(i[0])
    value.append(int(i[1]))
    s+=1

# %%
import pandas as pd
df = pd.DataFrame({
    'Части речи': tag,
    'Количество в текстах' : value

                  })
df.head(1)
# Out:
#   Части речи  Количество в текстах
# 0          S                 24794

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
df.plot.barh(x='Части речи', y='Количество в текстах', color='pink');
plt.ylabel('Части речи');
plt.title('10 самых частотных частей речи в книгах Сорокина');

plt.savefig('10pos.jpg')

# %% [markdown]
# # 15 самых частотных прилагательных

# %%
adj = ''
lem = lemmas.split(' ')
s = 0

for i in pos_tags.split(' '):
    
    if i == 'A':
        adj += lem[s] 
        adj += ' '
    s +=1

# %%
b = Counter(adj.split(' ')).most_common(15)
adject = []
value = []

s = 0
for i in b:
    adject.append(i[0])
    value.append(int(i[1]))
    s+=1

# %%
df1 = pd.DataFrame({
    'Прилагательные': adject,
    'Количество в текстах' : value

                  })
df1.head(1)
# Out:
#   Прилагательные  Количество в текстах
# 0        большой                   114

# %%
df1.plot.barh(x='Прилагательные', y='Количество в текстах', color='green');
plt.ylabel('Прилагательные');
plt.title('15 самых частотных прилагательных в книгах Сорокина');

plt.savefig('15adj.jpg')

# %% [markdown]
# # Посмотрим, сколько существительных из всех являются матом и неприличными словами (жопа, говно, дерьмо) (извините)

# %%
s = 0
for i in lemmas.split(' '):
    if i == "хуй":
        s+= 1
    elif i == "блять":
        s+= 1
    elif i == "пиздец":
        s+= 1
    elif i == "сука":
        s+= 1
    elif i == "нахуй":
        s+= 1
    elif i == "ебаный" or i == "блядь":
        s+= 1
    elif i == "хуйло":
        s+= 1
    elif i == "жопа" or i == "говно" or i == "дерьмо":
        s+= 1

# %%
n = 0

for i in pos_tags.split(' '):
    
    if i == 'S':
        n += 1

# %%
n = n - s
n
# Out:
# 24751

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(5, 3), subplot_kw=dict(aspect="equal"))

data= [ s,n]

ingredients = ['мат и всякое грубое', 'не мат']


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} )".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
  
                                  textprops=dict(color="b"))
ax.legend(wedges, ingredients,
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))


plt.setp(autotexts, size=13, weight="bold")
plt.title('сколько существительных из всех являются матом и неприличными словами (жопа, говно, дерьмо) ')
fig.savefig('nouns.png')
fig.show()
# Out:
# /Users/mariadolgodvorova/opt/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# # Посмотрим на биграммы

# %% [markdown]
# Что встречается чаще? Глагол + существительное (но нет существительного до глагола) или существительное + глагол (но нет существительного после глагола)

# %%
s = 0
verb_noun = 0
noun_verb = 0
pst = pos_tags.split(' ')
for p in pst:
    if pst[s] == 'V' and pst[s+1] == 'S'and pst[s-1] != 'S':
        verb_noun += 1
        s += 1
    elif pst[s] == 'V' and pst[s-1] == 'S' and pst[s+1] != 'S':
        noun_verb += 1
        s += 1
    else:
        s += 1

# %%
verb_noun
# Out:
# 2661

# %%
noun_verb
# Out:
# 4183

# %%
labels = ['Глагол + существительное', 'Существительное + глагол']
sizes = [verb_noun, noun_verb]
colors = ['yellowgreen', 'gold']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()
